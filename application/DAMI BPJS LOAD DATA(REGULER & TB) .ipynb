# %%
import pandas as pd

df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Reguler\202103_fkrtl.dta")

# Tampilkan 5 baris pertama
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872201 entries, 0 to 872200
# Data columns (total 55 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   PSTV01  872201 non-null  int32
#  1   PSTV02  872201 non-null  int32
#  2   PSTV15  872201 non-null  float32
#  3   FKP02   872201 non-null  object
#  4   FKL02   872201 non-null  object
#  5   FKL03   872201 non-null  datetime64[ns]
#  6   FKL04   872201 non-null  datetime64[ns]
#  7   FKL05   872201 non-null  category
#  8   FKL06   872201 non-null  category
#  9   FKL07   872201 non-null  category
#  10  FKL08   872201 non-null  category
#  11  FKL09   872201 non-null  category
#  12  FKL10   872201 non-null  category
#  13  FKL11   872201 non-null  category
#  14  FKL12   872201 non-null  category
#  15  FKL13   872201 non-null  category
#  16  FKL14   872201 non-null  category
#  17  FKL15   872201 non-null  category
#  18  FKL15A  872201 non-null  object
# ...

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Reguler\2015202101_kepesertaan.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#       PSTV01     PSTV02     PSTV03    PSTV04     PSTV05             PSTV06  \
# 0  135798314    6326929 1997-03-01      ANAK  LAKI-LAKI  TIDAK TERDEFINISI
# 1  135821984  135821984 1956-08-01   PESERTA  LAKI-LAKI  TIDAK TERDEFINISI
# 2   47640415   97101523 1993-10-01      ANAK  PEREMPUAN              CERAI
# 3   95736990   43313628 1965-09-01     ISTRI  PEREMPUAN              KAWIN
# 4   66860922   70450667 2010-06-24  TAMBAHAN  LAKI-LAKI        BELUM KAWIN
#
#       PSTV07    PSTV08       PSTV09      PSTV10                     PSTV11  \
# 0  KELAS III  PBI APBN  JAWA TENGAH  TEMANGGUNG  PEMERINTAH KABUPATEN/KOTA
# 1  KELAS III  PBI APBN  JAWA TENGAH      KENDAL  PEMERINTAH KABUPATEN/KOTA
# 2  KELAS III  PBI APBN  JAWA TENGAH      KENDAL  PEMERINTAH KABUPATEN/KOTA
# 3  KELAS III  PBI APBN  JAWA TENGAH      KENDAL  PEMERINTAH KABUPATEN/KOTA
# 4  KELAS III  PBI APBN  JAWA TENGAH  TEMANGGUNG                     SWASTA
#
# ...

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Reguler\202104_nonkapitasi.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#       PSTV01     PSTV02     PSTV15             PNK02      PNK03      PNK04  \
# 0   58535615   39540462   0.949749  140270421P000283 2021-04-18 2021-04-20
# 1   72754862   72754862   6.303136   88220121P001458 2021-01-26 2021-01-29
# 2  390220748  401640722  24.871052  433810421P000084 2021-04-30 2021-05-02
# 3   61351881   64119870  18.174042  199281021P000077 2021-10-02 2021-10-04
# 4   20965023   20965023  45.487633  420800621P000260 2021-06-09 2021-06-13
#
#        PNK05        PNK06            PNK07                      PNK08  ...  \
# 0 2021-04-20  JAWA TIMUR     KAB. LAMONGAN                     SWASTA  ...
# 1 2021-01-29  JAWA TIMUR    KAB. BANGKALAN  PEMERINTAH KABUPATEN/KOTA  ...
# 2 2021-05-02  JAWA TIMUR   KAB. TRENGGALEK                     SWASTA  ...
# 3 2021-10-04     LAMPUNG    KAB. TANGGAMUS                     SWASTA  ...
# 4 2021-06-13        ACEH   KAB. ACEH UTARA                     SWASTA  ...
#
# ...

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Reguler\202105_diagnosissekunder.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#               FKL02 FKL24 FKL24A  \
# 0  100080221V000625  S822    S82
# 1  100080721V000129  P282    P28
# 2  100080921V000849  N170    N17
# 3  100081121V000654  O800    O80
# 4  100081121V000764  O700    O70
#
#                                               FKL24B
# 0         S82 Fracture of lower leg, including ankle
# 1  P28 Other respiratory conditions originating i...
# 2                            N17 Acute renal failure
# 3                    O80 Single spontaneous delivery
# 4            O70 Perineal laceration during delivery

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Kontekstual TB\TB20152021_fkrtl.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#      PSTV01    PSTV02    PSTV15 FKP02             FKL02      FKL03      FKL04  \
# 0  96934726  96934726  0.899331        1000801150000582 2015-01-21 2015-01-21
# 1  11315168  11315168  0.938273        1000801150001076 2015-01-13 2015-01-13
# 2  48014275  20325942  0.998232        1000801160000002 2016-01-02 2016-01-06
# 3  78552717   3459550  1.205653        1000801160000219 2016-01-08 2016-01-08
# 4  48014275  20325942  0.998232        1000801160000321 2016-01-11 2016-01-11
#
#    FKL05     FKL06                FKL07  ... FKL39 FKL40 FKL41 FKL42 FKL43  \
# 0  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         NaN               NaN
# 1  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         NaN               NaN
# 2  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
# 3  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
# 4  PAPUA  JAYAPURA  Pemerintah kab/kota  ...         0.0               0.0
#
#   FKL44 FKL45 FKL46    FKL47    FKL48
# ...

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Kontekstual TB\TB20152021_fkrtldxsekunder.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#               FKL02  FKL24 FKL24A  \
# 0  2603412140001163   H814    H81
# 1  1337801150000108   M199    M19
# 2  1571901150000730  M4909    M49
# 3  3039201150000052   E790    E79
# 4  3376701150000072   N390    N39
#
#                                               FKL24B
# 0               H81 Disorders of vestibular function
# 1                                M19 Other arthrosis
# 2  M49 Spondylopathies in diseases classified els...
# 3  E79 Disorders of purine and pyrimidine metabolism
# 4              N39 Other disorders of urinary system

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Kontekstual TB\TB2019_kepesertaan.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06  \
# 0   21611150   21611150 1957-09-12  PESERTA  PEREMPUAN        KAWIN
# 1   94343049   96772919 1961-12-03    SUAMI  LAKI-LAKI        KAWIN
# 2   83393824  298548714 2002-10-05     ANAK  LAKI-LAKI  BELUM KAWIN
# 3  328537885  328537885 1989-07-13  PESERTA  PEREMPUAN  BELUM KAWIN
# 4   67805935   67805935 1972-11-13  PESERTA  LAKI-LAKI        KAWIN
#
#       PSTV07    PSTV08 PSTV09         PSTV10                     PSTV11  \
# 0    KELAS I       PPU   ACEH     ACEH BESAR  PEMERINTAH KABUPATEN/KOTA
# 1    KELAS I       PPU   ACEH  ACEH TENGGARA  PEMERINTAH KABUPATEN/KOTA
# 2    KELAS I       PPU   ACEH  ACEH TENGGARA  PEMERINTAH KABUPATEN/KOTA
# 3  KELAS III  PBI APBD   ACEH   ACEH TAMIANG  PEMERINTAH KABUPATEN/KOTA
# 4    KELAS I       PPU   ACEH   ACEH TAMIANG  PEMERINTAH KABUPATEN/KOTA
#
#       PSTV12 PSTV13         PSTV14    PSTV15  PSTV16 PSTV17  PSTV18
# ...

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Kontekstual TB\TB2020_kepesertaan.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06    PSTV07  \
# 0   32853965   31945523 1958-11-27    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 1    8555967    8555967 1936-07-01  PESERTA  LAKI-LAKI        KAWIN   KELAS I
# 2    8797049     249479 1950-07-21    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 3   83472658   54408870 2012-08-12     ANAK  PEREMPUAN  BELUM KAWIN   KELAS I
# 4  425874326  296852327 2004-12-30     ANAK  LAKI-LAKI  BELUM KAWIN  KELAS II
#
#           PSTV08          PSTV09        PSTV10                     PSTV11  \
# 0            PPU            ACEH   ACEH TENGAH  PEMERINTAH KABUPATEN/KOTA
# 1  BUKAN PEKERJA            ACEH   ACEH TENGAH                      POLRI
# 2  BUKAN PEKERJA            ACEH  ACEH SELATAN  PEMERINTAH KABUPATEN/KOTA
# 3            PPU            ACEH    ACEH BARAT  PEMERINTAH KABUPATEN/KOTA
# 4            PPU  SUMATERA UTARA  TOBA SAMOSIR  PEMERINTAH KABUPATEN/KOTA
#
# ...

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Kontekstual TB\TB2021_kepesertaan.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05       PSTV06    PSTV07  \
# 0   32853965   31945523 1958-11-27    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 1    8555967    8555967 1936-07-01  PESERTA  LAKI-LAKI        KAWIN   KELAS I
# 2    8797049     249479 1950-07-21    SUAMI  LAKI-LAKI        KAWIN   KELAS I
# 3   83472658   54408870 2012-08-12     ANAK  PEREMPUAN  BELUM KAWIN   KELAS I
# 4  425874326  296852327 2004-12-30     ANAK  LAKI-LAKI  BELUM KAWIN  KELAS II
#
#           PSTV08          PSTV09        PSTV10                     PSTV11  \
# 0            PPU            ACEH   ACEH TENGAH  PEMERINTAH KABUPATEN/KOTA
# 1  BUKAN PEKERJA            ACEH   ACEH TENGAH                      POLRI
# 2  BUKAN PEKERJA            ACEH  ACEH SELATAN  PEMERINTAH KABUPATEN/KOTA
# 3            PPU            ACEH    ACEH BARAT  PEMERINTAH KABUPATEN/KOTA
# 4            PPU  SUMATERA UTARA  TOBA SAMOSIR  PEMERINTAH KABUPATEN/KOTA
#
# ...

# %%
df = pd.read_stata(r"C:\Users\Septiana\Downloads\Final Project\Data Sampel Final 2022\Kontekstual TB\TB20152021_fktpnonkapitasi.dta")

# Tampilkan 5 baris pertama
df.head()
# Out:
#       PSTV01     PSTV02     PSTV15             PNK02      PNK03      PNK04  \
# 0   93858078   93216423   7.659537  183920215Y000376 2015-02-26 2015-02-26
# 1   93747649  346217457   1.800196   19500915Y000074 2015-09-21 2015-09-23
# 2  359887820   72989971   0.959155  250630919P000299 2019-09-26 2019-09-29
# 3   84126594   84126594   1.110887  326360919P001086 2019-09-09 2019-09-12
# 4   87558937   62126532  32.451832  252721019P001142 2019-10-14 2019-10-17
#
#        PNK05               PNK06     PNK07                      PNK08  ...  \
# 0 2015-02-27    SULAWESI SELATAN     BARRU  PEMERINTAH KABUPATEN/KOTA  ...
# 1 2015-09-23  KALIMANTAN SELATAN     TAPIN  PEMERINTAH KABUPATEN/KOTA  ...
# 2 2019-09-29               PAPUA  JAYAPURA                     TNI AD  ...
# 3 2019-09-12         JAWA TENGAH   REMBANG  PEMERINTAH KABUPATEN/KOTA  ...
# 4 2019-10-17         JAWA TENGAH   KEBUMEN  PEMERINTAH KABUPATEN/KOTA  ...
#
# ...
